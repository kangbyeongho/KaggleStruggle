# %% [markdown]
# <a href="https://colab.research.google.com/github/kangbyeongho/KaggleStruggle/blob/master/mission_2%EC%A3%BC%EC%B0%A8(%EC%B5%9C%EC%A2%85).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# program 1(에니텔텔)

# test score, mid : 50, final : 75
class Score():
    def __init__(self, mid, final):
        self.mid = mid
        self.final = final

#출력함수
score = Score(50,75)
print((score.mid + score.final)/2)
# Out:
# 62.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# program 2(에니텔)

'''  # super().__init__()이라는 코드가 다른 클래스의 속성 및 메소드를
     자동으로 불러와 해당 클래스에서도 사용이 가능하도록 해줍니다.'''

class Car():
    def __init__(self,fuel,wheels):
        self.fuel = fuel
        self.wheels = wheels
class Bike(Car):
    def __init__(self, fuel, wheels, size):
        super().__init__(fuel, wheels)
        self.size = size

# %%
#출력예시
bike = Bike("gas",2,"small")
print(bike.fuel,bike.wheels, bike.size)
# Out:
# gas 2 small

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 자료 다운로드
# https://www.boostcourse.org/downloadFile/fileDownload?attachmentId=4552930&autoClose=true

# %%
# 구글드라이브 마운트트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
score_list = [] #cutomer 개별 List를 저장하는 List
with open ("/content/drive/MyDrive/boostcourse/code/2주차/data-01-test-score.csv") as score_data: #customer.csv 파일을 customer_data 객체에 저장
    while True:
        data = score_data.readline() #score을 읽어 한줄씩 data 변수에 저장
        if not data: break #데이터가 없을 때, Loop 종료

        data=data.replace('\n','') #자료 끝에 있는 '\n'를 없앰
        score_list.append(data.split(",")) #일반 데이터는 score_list 객체에 저장, 데이터 저장시 “,”로 분리
        # line_counter += 1

for i in range(len(score_list)): #데이터 출력
    print(score_list[i]) 
    
print(len(score_list)) #전체 데이터 크기 출력
# Out:
# ['73', '80', '75', '152']
# ['93', '88', '93', '185']
# ['89', '91', '90', '180']
# ['96', '98', '100', '196']
# ['73', '66', '70', '142']
# ['53', '46', '55', '101']
# ['69', '74', '77', '149']
# ['47', '56', '60', '115']
# ['87', '79', '90', '175']
# ['79', '70', '88', '164']
# ['69', '70', '73', '141']
# ['70', '65', '74', '141']
# ['93', '95', '91', '184']
# ['79', '80', '73', '152']
# ['70', '73', '78', '148']
# ['93', '89', '96', '192']
# ['78', '75', '68', '147']
# ['81', '90', '93', '183']
# ['88', '92', '86', '177']
# ['78', '83', '77', '159']
# ['82', '86', '90', '177']
# ['86', '82', '89', '175']
# ['78', '83', '85', '175']
# ['76', '83', '71', '149']
# ['96', '93', '95', '192']
# 25

# %%
import csv
score_list=[]
f=open('/content/drive/MyDrive/boostcourse/code/2주차/data-01-test-score.csv')
data = csv.reader(f,delimiter=',')

for row in data:
    score_list.append(row)
f.close()
print(score_list)
# Out:
# [['73', '80', '75', '152'], ['93', '88', '93', '185'], ['89', '91', '90', '180'], ['96', '98', '100', '196'], ['73', '66', '70', '142'], ['53', '46', '55', '101'], ['69', '74', '77', '149'], ['47', '56', '60', '115'], ['87', '79', '90', '175'], ['79', '70', '88', '164'], ['69', '70', '73', '141'], ['70', '65', '74', '141'], ['93', '95', '91', '184'], ['79', '80', '73', '152'], ['70', '73', '78', '148'], ['93', '89', '96', '192'], ['78', '75', '68', '147'], ['81', '90', '93', '183'], ['88', '92', '86', '177'], ['78', '83', '77', '159'], ['82', '86', '90', '177'], ['86', '82', '89', '175'], ['78', '83', '85', '175'], ['76', '83', '71', '149'], ['96', '93', '95', '192']]

# %%
import csv
score_list=[]
file_path='/content/drive/MyDrive/boostcourse/code/2주차/data-01-test-score.csv'

core_list=[]
with open(file_path) as file:
    data = csv.reader(file,delimiter=',')

    for row in data:
        score_list.append(row)

print(score_list)
# Out:
# [['73', '80', '75', '152'], ['93', '88', '93', '185'], ['89', '91', '90', '180'], ['96', '98', '100', '196'], ['73', '66', '70', '142'], ['53', '46', '55', '101'], ['69', '74', '77', '149'], ['47', '56', '60', '115'], ['87', '79', '90', '175'], ['79', '70', '88', '164'], ['69', '70', '73', '141'], ['70', '65', '74', '141'], ['93', '95', '91', '184'], ['79', '80', '73', '152'], ['70', '73', '78', '148'], ['93', '89', '96', '192'], ['78', '75', '68', '147'], ['81', '90', '93', '183'], ['88', '92', '86', '177'], ['78', '83', '77', '159'], ['82', '86', '90', '177'], ['86', '82', '89', '175'], ['78', '83', '85', '175'], ['76', '83', '71', '149'], ['96', '93', '95', '192']]

# %%
# program 3_1
file_path='/content/drive/MyDrive/boostcourse/code/2주차/data-01-test-score.csv'

def read_file(file_path):
    score_list = [] #cutomer 개별 List를 저장하는 List
    with open (file_path) as score_data: #score.csv 파일을 score_data 객체에 저장
        while True:
            data = score_data.readline() #score을 읽어 한줄씩 data 변수에 저장
            if not data: break #데이터가 없을 때, Loop 종료

            data=data.replace('\n','') #자료 끝에 있는 '\n'를 없앰
            score_list.append(data.split(",")) #일반 데이터는 score_list 객체에 저장, 데이터 저장시 “,”로 분리
            # line_counter += 1
        return score_list

print(read_file(file_path))
# Out:
# [['73', '80', '75', '152'], ['93', '88', '93', '185'], ['89', '91', '90', '180'], ['96', '98', '100', '196'], ['73', '66', '70', '142'], ['53', '46', '55', '101'], ['69', '74', '77', '149'], ['47', '56', '60', '115'], ['87', '79', '90', '175'], ['79', '70', '88', '164'], ['69', '70', '73', '141'], ['70', '65', '74', '141'], ['93', '95', '91', '184'], ['79', '80', '73', '152'], ['70', '73', '78', '148'], ['93', '89', '96', '192'], ['78', '75', '68', '147'], ['81', '90', '93', '183'], ['88', '92', '86', '177'], ['78', '83', '77', '159'], ['82', '86', '90', '177'], ['86', '82', '89', '175'], ['78', '83', '85', '175'], ['76', '83', '71', '149'], ['96', '93', '95', '192']]

# %%
# program 3_2

import csv
file_path='/content/drive/MyDrive/boostcourse/code/2주차/data-01-test-score.csv'

def read_file(file_path):
    score_list = [] #cutomer 개별 List를 저장하는 List
    f=open(file_path)
    data = csv.reader(f,delimiter=',')

    for row in data:
        score_list.append(row)
    f.close()
    return score_list

print(read_file(file_path))
# Out:
# [['73', '80', '75', '152'], ['93', '88', '93', '185'], ['89', '91', '90', '180'], ['96', '98', '100', '196'], ['73', '66', '70', '142'], ['53', '46', '55', '101'], ['69', '74', '77', '149'], ['47', '56', '60', '115'], ['87', '79', '90', '175'], ['79', '70', '88', '164'], ['69', '70', '73', '141'], ['70', '65', '74', '141'], ['93', '95', '91', '184'], ['79', '80', '73', '152'], ['70', '73', '78', '148'], ['93', '89', '96', '192'], ['78', '75', '68', '147'], ['81', '90', '93', '183'], ['88', '92', '86', '177'], ['78', '83', '77', '159'], ['82', '86', '90', '177'], ['86', '82', '89', '175'], ['78', '83', '85', '175'], ['76', '83', '71', '149'], ['96', '93', '95', '192']]

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import csv
file_path='/content/drive/MyDrive/boostcourse/code/2주차/data-01-test-score.csv'

class ReadCSV():
    def __init__(self,file_path): 
        self.file_path=file_path

    def read_file(self,file_path):
        # score_list = [] #score 개별 List를 저장하는 List

        # f=open(self.file_path)
        # data = csv.reader(f,delimiter=',')

        # for row in data:
        #     score_list.append(row)

        # return score_list
        # f.close()

        with open(self.file_path) as file:
            csv_reader = csv.reader(file)
            for row in csv_reader:
                score_list.append(row)
        return score_list


    def merge_list(self):
        score = self.read_file()
        sum_list=[]
        for row in score:
            sum_list.append(sum([int(i) for i in row ]))
        return sum_list

file_path = '/content/drive/MyDrive/boostcourse/code/2주차/data-01-test-score.csv'
read_csv = ReadCSV(file_path)
print(read_csv.read_file())
print(read_csv.merge_list())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-5825cbfa01bd> in <module>
#      34 file_path = '/content/drive/MyDrive/boostcourse/code/2주차/data-01-test-score.csv'
#      35 read_csv = ReadCSV(file_path)
# ---> 36 print(read_csv.read_file())
#      37 print(read_csv.merge_list())
#
# TypeError: read_file() missing 1 required positional argument: 'file_path'

# %%
# program 4

import csv

class ReadCSV():
    def __init__(self, file_path):
        self.file_path = file_path

    def read_file(self):
        score_list = []
        with open(self.file_path) as file:
            csv_reader = csv.reader(file)
            for row in csv_reader:
                score_list.append(row)
        return score_list

    def merge_list(self):
        score_list = self.read_file()
        score_sum = []
        for row in score_list:
            score_sum.append(sum([int(i) for i in row])) #합계하여 list저장
        return score_sum

file_path = '/content/drive/MyDrive/boostcourse/code/2주차/data-01-test-score.csv'
read_csv = ReadCSV(file_path)
print(read_csv.read_file())
print(read_csv.merge_list())
# Out:
# [['73', '80', '75', '152'], ['93', '88', '93', '185'], ['89', '91', '90', '180'], ['96', '98', '100', '196'], ['73', '66', '70', '142'], ['53', '46', '55', '101'], ['69', '74', '77', '149'], ['47', '56', '60', '115'], ['87', '79', '90', '175'], ['79', '70', '88', '164'], ['69', '70', '73', '141'], ['70', '65', '74', '141'], ['93', '95', '91', '184'], ['79', '80', '73', '152'], ['70', '73', '78', '148'], ['93', '89', '96', '192'], ['78', '75', '68', '147'], ['81', '90', '93', '183'], ['88', '92', '86', '177'], ['78', '83', '77', '159'], ['82', '86', '90', '177'], ['86', '82', '89', '175'], ['78', '83', '85', '175'], ['76', '83', '71', '149'], ['96', '93', '95', '192']]
# [380, 459, 450, 490, 351, 255, 369, 278, 431, 401, 353, 350, 463, 384, 369, 470, 368, 447, 443, 397, 435, 432, 421, 379, 476]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# program 5

import csv

class ReadCSV():
    def __init__(self, file_path):
        self.file_path = file_path

    def read_file(self):
        score_list = []
        with open(self.file_path) as file:
            csv_reader = csv.reader(file)
            for row in csv_reader:
                score_list.append(row)
        return score_list

    def merge_list(self):
        score_list = self.read_file()
        avg = []
        for row in score_list:
            avg.append(sum([int(i) for i in row])/4) #합을 데이터수(len(row))나누어 준다다
        return avg

file_path = '/content/drive/MyDrive/boostcourse/code/2주차/data-01-test-score.csv'
read_csv = ReadCSV(file_path)
print(read_csv.merge_list())
# Out:
# [95.0, 114.75, 112.5, 122.5, 87.75, 63.75, 92.25, 69.5, 107.75, 100.25, 88.25, 87.5, 115.75, 96.0, 92.25, 117.5, 92.0, 111.75, 110.75, 99.25, 108.75, 108.0, 105.25, 94.75, 119.0]

# %%
file_path='./data-01-test-score.csv'

class ReadCSV():
    def __init__(self,file_path): 
        
        
    def read_file(self, #):
        

    def merge_list(self, #):   
        

read_csv=ReadCSV(filepath)
print(ReadCSV.read_file())
print(ReadCSV.merge_list()) 


출력예시
[['73', '80', '75', '152'], ['93', '88', '93', '185'], ['89', '91', '90', '180']]
[63.75,69.5,87.5]
